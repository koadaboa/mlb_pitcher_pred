# %%
from pybaseball import statcast_pitcher, statcast_batter, team_batting, statcast
import pandas as pd

# %%
df = statcast('2025-04-04', '2025-04-07')
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 4/4 [00:01<00:00,  3.66it/s]

# %%
df.head()
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2351         FF 2025-04-07           95.4          -2.65           5.79
# 2392         FS 2025-04-07           90.0           -2.6           5.71
# 2484         FF 2025-04-07           95.8           -2.6           5.78
# 2537         FF 2025-04-07           95.9          -2.75           5.82
# 2643         FF 2025-04-07           95.8          -2.63           5.75
#
#         player_name  batter  pitcher     events      description  ...  \
# 2351  Hoffman, Jeff  666152   656546  field_out    hit_into_play  ...
# 2392  Hoffman, Jeff  665966   656546  field_out    hit_into_play  ...
# 2484  Hoffman, Jeff  665966   656546       None             ball  ...
# 2537  Hoffman, Jeff  665966   656546       None    called_strike  ...
# 2643  Hoffman, Jeff  677800   656546  strikeout  swinging_strike  ...
#
#       n_thruorder_pitcher  n_priorpa_thisgame_player_at_bat  \
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('pitch_data.db')
df.to_sql('pitches', conn, if_exists='replace', index=False)
# Out:
# 15946

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type = 'table';")
print(cursor.fetchall())
# Out:
# [('pitches',)]

# %%
cursor.execute("SELECT * FROM pitches LIMIT 5")
print(cursor.fetchall())
# Out:
# [('FF', '2025-04-07 00:00:00', 95.4, -2.65, 5.79, 'Hoffman, Jeff', 666152, 656546, 'field_out', 'hit_into_play', None, None, None, None, 3, 'David Hamilton flies out to left fielder Alan Roden.', 'R', 'L', 'R', 'BOS', 'TOR', 'X', 7, 'fly_ball', 0, 0, 2025, -0.95, 1.61, 0.6, 2.74, None, None, None, 2, 9, 'Bot', 97.09, 123.31, None, None, None, None, 10.736929446018063, -138.2174312801077, -5.877537805407462, -14.844318590388358, 36.46809082658631, -10.4831164656062, 3.18, 1.45, 181, 93.0, 62, 94.9, 2548, 6.6, 778426, 672386, 665489, 665926, 676391, 666182, 702176, 664702, 543807, 53.86, 0.009, 0.011, 0.0, 1, 0, 0, 3, 79, 1, '4-Seam Fastball', 2, 6, 2, 6, 6, 2, 2, 6, 'Infield shade', 'Standard', 222, -0.001, -0.256, 73.9, 7.0, 0.017, 0.256, 93.0, -4, -4, 0.001, 0.001, 32, 27, 32, 28, 1, 3, None, None, None, None, 0.96, 0.95, -0.95, None), ('FS', '2025-04-07 00:00:00', 90.0, -2.6, 5.71, 'Hoffman, Jeff', 665966, 656546, 'field_out', 'hit_into_play', None, None, None, None, 14, 'Carlos Na
# ...

# %%
df_loaded = pd.read_sql_query("SELECT * FROM pitches", conn)

# %%
df_loaded.head()
# Out:
#   pitch_type            game_date  release_speed  release_pos_x  \
# 0         FF  2025-04-07 00:00:00           95.4          -2.65
# 1         FS  2025-04-07 00:00:00           90.0          -2.60
# 2         FF  2025-04-07 00:00:00           95.8          -2.60
# 3         FF  2025-04-07 00:00:00           95.9          -2.75
# 4         FF  2025-04-07 00:00:00           95.8          -2.63
#
#    release_pos_z    player_name  batter  pitcher     events      description  \
# 0           5.79  Hoffman, Jeff  666152   656546  field_out    hit_into_play
# 1           5.71  Hoffman, Jeff  665966   656546  field_out    hit_into_play
# 2           5.78  Hoffman, Jeff  665966   656546       None             ball
# 3           5.82  Hoffman, Jeff  665966   656546       None    called_strike
# 4           5.75  Hoffman, Jeff  677800   656546  strikeout  swinging_strike
#
#    ... n_thruorder_pitcher n_priorpa_thisgame_player_at_bat  \
# ...

# %%
conn.close()
